# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randint(0, 100, 40)
y = np.random.randint(0, 100, 40)
z = np.random.randint(0, 100, 40)

# %%
fig,axs = plt.subplots(2, 1)
axs[0].plot(x, x**2, linewidth = 10, color='orange')
axs[1].plot(x, -y, )
